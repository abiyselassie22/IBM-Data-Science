# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align=center><font size = 5>Assignment: Notebook for Peer Assignment</font></h1>

# %% [markdown]
# # Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand three Chicago datasets
# 2.  Load the three datasets into three tables in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Understand the datasets
#
# To complete the assignment problems in this notebook you will be using three datasets that are available on the city of Chicago's Data Portal:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Socioeconomic Indicators in Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Public Schools</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to have these three tables populated with a subset of the whole datasets.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the links below to download and save the datasets (.CSV files):
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Census Data</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Public Schools</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Crime Data</a>
#
# **NOTE:** Ensure you have downloaded the datasets using the links above instead of directly from the Chicago Data Portal. The versions linked here are subsets of the original datasets and have some of the column names modified to be more database friendly which will make it easier to complete this assignment.

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be loaded into SQLite DB.
# We will create three tables in as under:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**
#
# Let us now load the ipython-sql  extension and establish a connection with the database
#
# *   Here you will be loading the csv files into the pandas Dataframe and then loading the data into the above mentioned sqlite tables.
#
# *   Next you will be connecting to the sqlite database  **FinalDB**.
#
# Refer to the previous lab for hints .
#
# <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing_SQLite.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01">Hands-on Lab: Analyzing a real World Data Set</a>

# %%
# %load_ext sql

# %%
# %sql sqlite:///RealWorldData.db

# %%
# !pip install -q pandas==1.1.5

# %%
import csv, sqlite3
con = sqlite3.connect("RealWorldData.db")
cur = con.cursor()

# %%
import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv")
df.to_sql("CENSUS_DATA", con, if_exists='replace', index=False, method="multi")

df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv")
df.to_sql("CHICAGO_CRIME_DATA", con, if_exists='replace', index=False, method="multi")

df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv")
df.to_sql("CHICAGO_PUBLIC_SCHOOLS_DATA", con, if_exists='replace', index=False, method="multi")
# Out:
# C:\Users\Gasha\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT Count(*) AS TOTAL_CRIMES From CHICAGO_CRIME_DATA;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %sql SELECT Community_Area_Name FROM CENSUS_DATA WHERE Per_Capita_Income < 11000;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('West Garfield Park',),
#  ('South Lawndale',),
#  ('Fuller Park',),
#  ('Riverdale',)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes  involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %%sql SELECT CASE_NUMBER
# FROM CHICAGO_CRIME_DATA
# WHERE DESCRIPTION LIKE '%MINOR%';
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %%sql SELECT CASE_NUMBER, PRIMARY_TYPE, DATE, DESCRIPTION
# FROM CHICAGO_CRIME_DATA
# WHERE PRIMARY_TYPE = 'KIDNAPPING';
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('HN144152', 'KIDNAPPING', '2007-01-26', 'CHILD ABDUCTION/STRANGER')]

# %% [markdown]
# ### Problem 5
#
# ##### What kinds of crimes were recorded at schools?

# %%
# %%sql SELECT DISTINCT(Primary_Type), Location_Description
# FROM CHICAGO_CRIME_DATA
# WHERE Location_Description LIKE '%SCHOOL%';
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('BATTERY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('CRIMINAL DAMAGE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, BUILDING'),
#  ('ASSAULT', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL TRESPASS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PRIVATE, BUILDING'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PUBLIC, BUILDING')]

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for each type of school.

# %%
# %%sql SELECT "Elementary, Middle, or High School", AVG(Safety_Score) AS AVERAGE_SAFETY_SCORE
# FROM CHICAGO_PUBLIC_SCHOOLS
# Group by "Elementary, Middle, or High School"
# Out:
#  * sqlite:///RealWorldData.db
# (sqlite3.OperationalError) near "or": syntax error
# [SQL: SELECT Elementary, Middle, or High School , AVG(Safety_Score) AS AVERAGE_SAFETY_SCORE
# FROM CHICAGO_PUBLIC_SCHOOLS
# Group by "Elementary, Middle, or High School"]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %sql SELECT Community_Area_Name, Percent_Households_Below_Poverty FROM CENSUS_DATA\
Order by Percent_Households_Below_Poverty Desc Nulls Last Limit 5
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone?

# %%
# %%sql SELECT Community_Area_Number, COUNT(Community_Area_Number) AS Frequency
# FROM CHICAGO_CRIME_DATA
# Group by Community_Area_Number
# Order by COUNT(Community_Area_Number) Desc
# Limit 1
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(25.0, 43)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Query for the 'community area number' that is most crime prone.
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %%sql SELECT Community_Area_Name FROM CENSUS_DATA
# WHERE Hardship_Index = (select MAX(Hardship_Index) FROM CENSUS_DATA)
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Riverdale',)]

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %%sql SELECT Community_Area_Name, Community_Area_Number FROM CENSUS_DATA
# WHERE Community_Area_Number =
# (select Community_Area_Number FROM CHICAGO_CRIME_DATA
#  Group By Community_Area_Number
#  Order BY COUNT(Community_Area_Number) DESC
#  Limit 1)
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Austin', 25.0)]

# %% [markdown]
# Copyright © 2020 This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %%
# %%sql SELECT CCD.Case_Number, CCD.Primary_Type, CD.Community_Area_Name, CD.Community_Area_Number
# from CHICAGO_CRIME_DATA as CCD
# INNER JOIN CENSUS_DATA as CD
# On CCD. Community_Area_Number = CD. Community_Area_Number
# Where CCD. Community_Area_Number ='18';
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('JA560123', 'CRIMINAL DAMAGE', 'Montclaire', 18.0),
#  ('JA107722', 'OTHER OFFENSE', 'Montclaire', 18.0)]

# %%
# %%sql SELECT CCD.Case_Number, CCD.Primary_Type, CCD.Location_Description, CCD. Community_Area_Number, CD.Community_Area_Name
# from CHICAGO_CRIME_DATA as CCD
# LEFT OUTER JOIN CENSUS_DATA as CD
# on CCD. Community_Area_Number = CD. Community_Area_Number;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('HK587712', 'THEFT', 'SMALL RETAIL STORE', 58.0, 'Brighton Park'),
#  ('HK456306', 'THEFT', 'OTHER', 23.0, 'Humboldt park'),
#  ('HT233595', 'THEFT', 'NURSING HOME/RETIREMENT HOME', 38.0, 'Grand Boulevard'),
#  ('HT133522', 'THEFT', 'RESIDENCE', 46.0, 'South Chicago'),
#  ('HZ138551', 'THEFT', 'ALLEY', 66.0, 'Chicago Lawn'),
#  ('HS540106', 'THEFT', 'PARKING LOT/GARAGE(NON.RESID.)', 24.0, 'West Town'),
#  ('HZ534771', 'THEFT', 'STREET', 14.0, 'Albany Park'),
#  ('HL793243', 'THEFT', 'GROCERY FOOD STORE', 38.0, 'Grand Boulevard'),
#  ('HL149610', 'THEFT', 'STREET', 72.0, 'Beverly'),
#  ('HK361551', 'THEFT', 'SMALL RETAIL STORE', 21.0, 'Avondale'),
#  ('HX552797', 'THEFT', 'DEPARTMENT STORE', 65.0, 'West Lawn'),
#  ('HT180228', 'THEFT', 'BAR OR TAVERN', 28.0, 'Near West Side'),
#  ('HV243612', 'THEFT', 'RESIDENTIAL YARD (FRONT/BACK)', 49.0, 'Roseland'),
#  ('HN200365', 'THEFT', 'OTHER', 28.0, 'Near West Side'),
#  ('HK108680', 'THEFT', 'RESIDENCE PORCH/HALLWAY', 26.0, 'West Garfield Park'),
#  ('HY396729', 'THEFT', 'PARKING LOT/GARAGE(NON.RESID.)', 22.0, 'Logan Square'),
#  ('HR271603', 'THEFT', 'OTHER', 48.0, 'Calumet Heights'),
#  ('HX332132', 'THEFT', 'CTA PLATFORM', 44.0, 'Chatham'),
#  ('HW303994', 'THEFT', 'VACANT LOT/LAND', 25.0, 'Austin'),
#  ('HS569246', 'THEFT', 'SIDEWALK', 25.0, 'Austin'),
#  ('HY234744', 'THEFT', 'DEPARTMENT STORE', 8.0, 'Near North Side'),
#  ('HP320451', 'THEFT', 'DEPARTMENT STORE', 32.0, 'Loop'),
#  ('HN484464', 'THEFT', 'STREET', 69.0, 'Greater Grand Crossing'),
#  ('JB151690', 'THEFT', 'GROCERY FOOD STORE', 59.0, 'McKinley Park'),
#  ('HR582990', 'THEFT', 'STREET', 68.0, 'Englewood'),
#  ('HR535632', 'THEFT', 'ATHLETIC CLUB', 14.0, 'Albany Park'),
#  ('HH486939', 'THEFT', 'AIRPORT/AIRCRAFT', 76.0, "O'Hare"),
#  ('HW441620', 'THEFT', 'STREET', 66.0, 'Chicago Lawn'),
#  ('HJ561433', 'THEFT', 'PARKING LOT/GARAGE(NON.RESID.)', 73.0, 'Washington Height'),
#  ('HR583513', 'THEFT', 'STREET', 44.0, 'Chatham'),
#  ('HX509438', 'THEFT', 'OTHER', 32.0, 'Loop'),
#  ('HS681158', 'THEFT', 'APARTMENT', 35.0, 'Douglas'),
#  ('HK350670', 'THEFT', 'SMALL RETAIL STORE', 6.0, 'Lake View'),
#  ('G256545', 'THEFT', 'SMALL RETAIL STORE', None, None),
#  ('JA272438', 'THEFT', 'SIDEWALK', 30.0, 'South Lawndale'),
#  ('HH201585', 'THEFT', 'BAR OR TAVERN', None, None),
#  ('G212935', 'THEFT', 'MOVIE HOUSE/THEATER', None, None),
#  ('HL590300', 'THEFT', 'STREET', 23.0, 'Humboldt park'),
#  ('HL409680', 'THEFT', 'STREET', 68.0, 'Englewood'),
#  ('HM324025', 'THEFT', 'GROCERY FOOD STORE', 8.0, 'Near North Side'),
#  ('G662598', 'THEFT', 'DEPARTMENT STORE', None, None),
#  ('HV353560', 'THEFT', 'RESIDENCE', 43.0, 'South Shore'),
#  ('HR261581', 'THEFT', 'GROCERY FOOD STORE', 31.0, 'Lower West Side'),
#  ('HL680775', 'THEFT', 'VEHICLE NON-COMMERCIAL', 24.0, 'West Town'),
#  ('HM543491', 'THEFT', 'STREET', 5.0, 'North Center'),
#  ('HY167451', 'THEFT', 'SIDEWALK', 68.0, 'Englewood'),
#  ('HY377901', 'THEFT', 'SIDEWALK', 22.0, 'Logan Square'),
#  ('HX225704', 'THEFT', 'RESTAURANT', 32.0, 'Loop'),
#  ('HJ308632', 'THEFT', 'RESIDENCE-GARAGE', 25.0, 'Austin'),
#  ('HV528008', 'THEFT', 'NURSING HOME/RETIREMENT HOME', 6.0, 'Lake View'),
#  ('HK801112', 'THEFT', 'STREET', 68.0, 'Englewood'),
#  ('HS532107', 'THEFT', 'APARTMENT', 42.0, 'Woodlawn'),
#  ('JA261898', 'THEFT', 'STREET', 25.0, 'Austin'),
#  ('JA559176', 'THEFT', 'RESIDENCE', 29.0, 'North Lawndale'),
#  ('JA412895', 'THEFT', 'RESIDENTIAL YARD (FRONT/BACK)', 23.0, 'Humboldt park'),
#  ('HY273740', 'THEFT', 'BAR OR TAVERN', 8.0, 'Near North Side'),
#  ('HZ224258', 'THEFT', 'STREET', 25.0, 'Austin'),
#  ('HJ652747', 'THEFT', 'STREET', 28.0, 'Near West Side'),
#  ('G040244', 'THEFT', 'GROCERY FOOD STORE', None, None),
#  ('HJ415128', 'THEFT', 'VEHICLE NON-COMMERCIAL', 59.0, 'McKinley Park'),
#  ('HV534721', 'THEFT', 'DEPARTMENT STORE', 7.0, 'Lincoln Park'),
#  ('JA503725', 'THEFT', 'STREET', 67.0, 'West Englewood'),
#  ('HM803061', 'THEFT', 'GROCERY FOOD STORE', 6.0, 'Lake View'),
#  ('HN731220', 'THEFT', 'COMMERCIAL / BUSINESS OFFICE', 32.0, 'Loop'),
#  ('HP691879', 'THEFT', 'APARTMENT', 39.0, 'Kenwood'),
#  ('HV537004', 'THEFT', 'OTHER', 77.0, 'Edgewater'),
#  ('HR149903', 'THEFT', 'TAVERN/LIQUOR STORE', 6.0, 'Lake View'),
#  ('HX314361', 'THEFT', 'STREET', 31.0, 'Lower West Side'),
#  ('HV345270', 'THEFT', 'CONSTRUCTION SITE', 61.0, 'New City'),
#  ('HS308747', 'THEFT', 'GAS STATION', 49.0, 'Roseland'),
#  ('HK728309', 'THEFT', 'STREET', 23.0, 'Humboldt park'),
#  ('HL005270', 'THEFT', 'GAS STATION', 25.0, 'Austin'),
#  ('HY291329', 'THEFT', 'DRUG STORE', 2.0, 'West Ridge'),
#  ('HJ678713', 'THEFT', 'PARKING LOT/GARAGE(NON.RESID.)', 63.0, 'Gage Park'),
#  ('HY412959', 'THEFT', 'RESIDENCE', 67.0, 'West Englewood'),
#  ('HX155070', 'THEFT', 'PARKING LOT/GARAGE(NON.RESID.)', 69.0, 'Greater Grand Crossing'),
#  ('HV402967', 'THEFT', 'STREET', 64.0, 'Clearing'),
#  ('HX332979', 'THEFT', 'APARTMENT', 62.0, 'West Elsdon'),
#  ('HJ710634', 'THEFT', 'STREET', 66.0, 'Chicago Lawn'),
#  ('HX165034', 'THEFT', 'RESIDENCE', 75.0, 'Morgan Park'),
#  ('HR385117', 'THEFT', 'SMALL RETAIL STORE', 65.0, 'West Lawn'),
#  ('HS230912', 'THEFT', 'RESIDENCE PORCH/HALLWAY', 49.0, 'Roseland'),
#  ('HL177398', 'THEFT', 'DEPARTMENT STORE', 22.0, 'Logan Square'),
#  ('HH702524', 'THEFT', 'STREET', 28.0, 'Near West Side'),
#  ('JA384163', 'THEFT', 'RESIDENCE', 21.0, 'Avondale'),
#  ('HJ672058', 'THEFT', 'STREET', 24.0, 'West Town'),
#  ('HT368471', 'THEFT', 'RESIDENCE PORCH/HALLWAY', 1.0, 'Rogers Park'),
#  ('HY202462', 'THEFT', 'STREET', 15.0, 'Portage Park'),
#  ('HX354359', 'THEFT', 'CTA BUS', 30.0, 'South Lawndale'),
#  ('HZ146741', 'THEFT', 'STREET', 71.0, 'Auburn Gresham'),
#  ('G376790', 'THEFT', 'DEPARTMENT STORE', None, None),
#  ('HX262353', 'THEFT', 'STREET', 76.0, "O'Hare"),
#  ('HP317516', 'THEFT', 'STREET', 64.0, 'Clearing'),
#  ('HZ335434', 'THEFT', 'STREET', 16.0, 'Irving Park'),
#  ('HS678732', 'THEFT', 'STREET', 68.0, 'Englewood'),
#  ('HL382289', 'THEFT', 'STREET', 8.0, 'Near North Side'),
#  ('HM392612', 'THEFT', 'STREET', 77.0, 'Edgewater'),
#  ('HH869886', 'THEFT', 'GROCERY FOOD STORE', 25.0, 'Austin'),
#  ('HR460350', 'THEFT', 'STREET', 67.0, 'West Englewood'),
#  ('HM117889', 'THEFT', 'OTHER', 50.0, 'Pullman'),
#  ('HR576816', 'THEFT', 'PARKING LOT/GARAGE(NON.RESID.)', 14.0, 'Albany Park'),
#  ('HZ372381', 'THEFT', 'VEHICLE NON-COMMERCIAL', 28.0, 'Near West Side'),
#  ('HZ556726', 'THEFT', 'STREET', 73.0, 'Washington Height'),
#  ('HN421595', 'THEFT', 'OTHER', 56.0, 'Garfield Ridge'),
#  ('HK454598', 'THEFT', 'VEHICLE NON-COMMERCIAL', 25.0, 'Austin'),
#  ('HH657809', 'THEFT', 'STREET', 51.0, 'South Deering'),
#  ('HS451246', 'BATTERY', 'SIDEWALK', 5.0, 'North Center'),
#  ('HH316735', 'BATTERY', 'GROCERY FOOD STORE', None, None),
#  ('G597730', 'BATTERY', 'STREET', None, None),
#  ('G736811', 'BATTERY', 'RESIDENCE', None, None),
#  ('HT651635', 'BATTERY', 'PARKING LOT/GARAGE(NON.RESID.)', 25.0, 'Austin'),
#  ('HZ432273', 'BATTERY', 'DRUG STORE', 21.0, 'Avondale'),
#  ('G517474', 'BATTERY', 'RESIDENCE', None, None),
#  ('HP746347', 'BATTERY', 'VEHICLE NON-COMMERCIAL', 2.0, 'West Ridge'),
#  ('G056330', 'BATTERY', 'RESIDENCE PORCH/HALLWAY', None, None),
#  ('HN772519', 'BATTERY', 'SIDEWALK', 71.0, 'Auburn Gresham'),
#  ('HZ309936', 'BATTERY', 'APARTMENT', 39.0, 'Kenwood'),
#  ('HY368284', 'BATTERY', 'APARTMENT', 30.0, 'South Lawndale'),
#  ('HL353697', 'BATTERY', 'SCHOOL, PUBLIC, GROUNDS', 43.0, 'South Shore'),
#  ('HT375934', 'BATTERY', 'SIDEWALK', 68.0, 'Englewood'),
#  ('JA188596', 'BATTERY', 'APARTMENT', 61.0, 'New City'),
#  ('HL725506', 'BATTERY', 'SCHOOL, PUBLIC, BUILDING', 4.0, 'Lincoln Square'),
#  ('HV395700', 'BATTERY', 'SIDEWALK', 29.0, 'North Lawndale'),
#  ('HH696901', 'BATTERY', 'SIDEWALK', 43.0, 'South Shore'),
#  ('HT390647', 'BATTERY', 'SIDEWALK', 27.0, 'East Garfield Park'),
#  ('HK815196', 'BATTERY', 'APARTMENT', 24.0, 'West Town'),
#  ('JA490957', 'BATTERY', 'RESIDENTIAL YARD (FRONT/BACK)', 49.0, 'Roseland'),
#  ('HK103473', 'BATTERY', 'SIDEWALK', 21.0, 'Avondale'),
#  ('HM556695', 'BATTERY', 'SIDEWALK', 23.0, 'Humboldt park'),
#  ('HH558381', 'BATTERY', 'SIDEWALK', 25.0, 'Austin'),
#  ('HK498590', 'BATTERY', 'APARTMENT', 8.0, 'Near North Side'),
#  ('HX455839', 'BATTERY', 'RESIDENCE', 50.0, 'Pullman'),
#  ('HR703960', 'BATTERY', 'RESIDENCE', 25.0, 'Austin'),
#  ('HL646682', 'BATTERY', 'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 73.0, 'Washington Height'),
#  ('HV445580', 'BATTERY', 'RESTAURANT', 6.0, 'Lake View'),
#  ('G688026', 'BATTERY', 'SIDEWALK', None, None),
#  ('HJ466766', 'BATTERY', 'SIDEWALK', 68.0, 'Englewood'),
#  ('HL632721', 'BATTERY', 'APARTMENT', 31.0, 'Lower West Side'),
#  ('HP579910', 'BATTERY', 'STREET', 42.0, 'Woodlawn'),
#  ('HL718742', 'BATTERY', 'RESIDENCE PORCH/HALLWAY', 23.0, 'Humboldt park'),
#  ('HP714065', 'BATTERY', 'RESIDENCE', 25.0, 'Austin'),
#  ('HP716225', 'BATTERY', 'SCHOOL, PUBLIC, BUILDING', 35.0, 'Douglas'),
#  ('HW481295', 'BATTERY', 'APARTMENT', 29.0, 'North Lawndale'),
#  ('HS568476', 'BATTERY', 'STREET', 30.0, 'South Lawndale'),
#  ('JB213238', 'BATTERY', 'RESIDENCE', 19.0, 'Belmont Cragin'),
#  ('HS475732', 'BATTERY', 'RESIDENCE', 19.0, 'Belmont Cragin'),
#  ('HS595785', 'BATTERY', 'SIDEWALK', 46.0, 'South Chicago'),
#  ('HR408597', 'BATTERY', 'RESIDENCE', 27.0, 'East Garfield Park'),
#  ('HT542713', 'BATTERY', 'RESTAURANT', 6.0, 'Lake View'),
#  ('HL240985', 'BATTERY', 'STREET', 7.0, 'Lincoln Park'),
#  ('HJ254782', 'BATTERY', 'STREET', 19.0, 'Belmont Cragin'),
#  ('HK561262', 'BATTERY', 'RESIDENCE', 29.0, 'North Lawndale'),
#  ('HW213573', 'BATTERY', 'PARKING LOT/GARAGE(NON.RESID.)', 43.0, 'South Shore'),
#  ('G419948', 'BATTERY', 'STREET', None, None),
#  ('HL177008', 'BATTERY', 'SIDEWALK', 68.0, 'Englewood'),
#  ('HJ639869', 'BATTERY', 'DEPARTMENT STORE', 37.0, 'Fuller Park'),
#  ('HM217017', 'BATTERY', 'SIDEWALK', 68.0, 'Englewood'),
#  ('HL388623', 'BATTERY', 'SIDEWALK', 26.0, 'West Garfield Park'),
#  ('HY189363', 'BATTERY', 'DEPARTMENT STORE', 32.0, 'Loop'),
#  ('HS498285', 'BATTERY', 'APARTMENT', 6.0, 'Lake View'),
#  ('HN224900', 'BATTERY', 'STREET', 30.0, 'South Lawndale'),
#  ('HR387668', 'BATTERY', 'SIDEWALK', 67.0, 'West Englewood'),
#  ('HJ294892', 'BATTERY', 'RESIDENCE', 25.0, 'Austin'),
#  ('HL745027', 'BATTERY', 'STREET', 69.0, 'Greater Grand Crossing'),
#  ('G533278', 'BATTERY', 'OTHER', None, None),
#  ('HH827769', 'BATTERY', 'OTHER COMMERCIAL TRANSPORTATION', 25.0, 'Austin'),
#  ('HH639427', 'BATTERY', 'SCHOOL, PUBLIC, BUILDING', 25.0, 'Austin'),
#  ('HK771992', 'BATTERY', 'APARTMENT', 29.0, 'North Lawndale'),
#  ('HH867007', 'BATTERY', 'RESIDENCE', 16.0, 'Irving Park'),
#  ('HJ575773', 'BATTERY', 'RESIDENCE PORCH/HALLWAY', 28.0, 'Near West Side'),
#  ('HR136920', 'BATTERY', 'CHA APARTMENT', 28.0, 'Near West Side'),
#  ('HT457930', 'BATTERY', 'SMALL RETAIL STORE', 23.0, 'Humboldt park'),
#  ('G070193', 'BATTERY', 'RESIDENCE', None, None),
#  ('HJ724585', 'BATTERY', 'APARTMENT', 29.0, 'North Lawndale'),
#  ('HP121474', 'BATTERY', 'STREET', 7.0, 'Lincoln Park'),
#  ('G198370', 'BATTERY', 'RESIDENCE', None, None),
#  ('HJ723825', 'BATTERY', 'APARTMENT', 39.0, 'Kenwood'),
#  ('HJ458342', 'BATTERY', 'APARTMENT', 8.0, 'Near North Side'),
#  ('HP558812', 'BATTERY', 'RESIDENCE', 62.0, 'West Elsdon'),
#  ('HY192694', 'BATTERY', 'APARTMENT', 66.0, 'Chicago Lawn'),
#  ('HN472326', 'BATTERY', 'RESIDENCE', 23.0, 'Humboldt park'),
#  ('HK756778', 'BATTERY', 'SIDEWALK', 61.0, 'New City'),
#  ('HH741961', 'BATTERY', 'STREET', 25.0, 'Austin'),
#  ('JA460432', 'BATTERY', 'SCHOOL, PUBLIC, GROUNDS', 70.0, 'Ashburn'),
#  ('G140454', 'BATTERY', 'APARTMENT', None, None),
#  ('HX239866', 'BATTERY', 'SIDEWALK', 27.0, 'East Garfield Park'),
#  ('HM378171', 'BATTERY', 'STREET', 37.0, 'Fuller Park'),
#  ('HW182288', 'BATTERY', 'RESIDENCE', 38.0, 'Grand Boulevard'),
#  ('HZ295843', 'BATTERY', 'STREET', 29.0, 'North Lawndale'),
#  ('HM673431', 'BATTERY', 'RESIDENCE', 49.0, 'Roseland'),
#  ('HP352546', 'BATTERY', 'SIDEWALK', 61.0, 'New City'),
#  ('HR286405', 'BATTERY', 'APARTMENT', 25.0, 'Austin'),
#  ('HR195987', 'BATTERY', 'SIDEWALK', 69.0, 'Greater Grand Crossing'),
#  ('HW261668', 'BATTERY', 'RESIDENCE', 26.0, 'West Garfield Park'),
#  ('JA496716', 'BATTERY', 'RESIDENCE', 24.0, 'West Town'),
#  ('JA344492', 'BATTERY', 'APARTMENT', 54.0, 'Riverdale'),
#  ('HZ334220', 'BATTERY', 'STREET', 2.0, 'West Ridge'),
#  ('HR217367', 'BATTERY', 'SIDEWALK', 25.0, 'Austin'),
#  ('HV268964', 'CRIMINAL DAMAGE', 'STREET', 60.0, 'Bridgeport'),
#  ('JA483294', 'CRIMINAL DAMAGE', 'STREET', 67.0, 'West Englewood'),
#  ('HT169840', 'CRIMINAL DAMAGE', 'RESIDENCE-GARAGE', 58.0, 'Brighton Park'),
#  ('HT621306', 'CRIMINAL DAMAGE', 'STREET', 10.0, 'Norwood Park'),
#  ('HS269736', 'CRIMINAL DAMAGE', 'STREET', 41.0, 'Hyde Park'),
#  ('HK243330', 'CRIMINAL DAMAGE', 'APARTMENT', 52.0, 'East Side'),
#  ('HH262924', 'CRIMINAL DAMAGE', 'SIDEWALK', None, None),
#  ('HL613433', 'CRIMINAL DAMAGE', 'RESIDENCE', 24.0, 'West Town'),
#  ('HY267896', 'CRIMINAL DAMAGE', 'RESIDENTIAL YARD (FRONT/BACK)', 53.0, 'West Pullman'),
#  ('HN568531', 'CRIMINAL DAMAGE', 'RESIDENCE', 61.0, 'New City'),
#  ('HT112422', 'CRIMINAL DAMAGE', 'RESIDENCE', 58.0, 'Brighton Park'),
#  ('HV479133', 'CRIMINAL DAMAGE', 'APARTMENT', 6.0, 'Lake View'),
#  ('HV592346', 'CRIMINAL DAMAGE', 'STREET', 23.0, 'Humboldt park'),
#  ('HH619797', 'CRIMINAL DAMAGE', 'STREET', 31.0, 'Lower West Side'),
#  ('HZ376709', 'CRIMINAL DAMAGE', 'APARTMENT', 44.0, 'Chatham'),
#  ('HV573337', 'CRIMINAL DAMAGE', 'APARTMENT', 29.0, 'North Lawndale'),
#  ('HL269210', 'CRIMINAL DAMAGE', 'STREET', 22.0, 'Logan Square'),
#  ('HL567458', 'CRIMINAL DAMAGE', 'RESIDENCE', 66.0, 'Chicago Lawn'),
#  ('HR674429', 'CRIMINAL DAMAGE', 'RESIDENCE', 63.0, 'Gage Park'),
#  ('HM200888', 'CRIMINAL DAMAGE', 'RESIDENCE', 10.0, 'Norwood Park'),
#  ('HX467661', 'CRIMINAL DAMAGE', 'STREET', 29.0, 'North Lawndale'),
#  ('HX448587', 'CRIMINAL DAMAGE', 'STREET', 50.0, 'Pullman'),
#  ('HS200939', 'CRIMINAL DAMAGE', 'SCHOOL, PUBLIC, GROUNDS', 25.0, 'Austin'),
#  ('HN335611', 'CRIMINAL DAMAGE', 'RESTAURANT', 15.0, 'Portage Park'),
#  ('HZ535494', 'CRIMINAL DAMAGE', 'STREET', 58.0, 'Brighton Park'),
#  ('HX154767', 'CRIMINAL DAMAGE', 'RESIDENCE-GARAGE', 4.0, 'Lincoln Square'),
#  ('HM337445', 'CRIMINAL DAMAGE', 'STREET', 19.0, 'Belmont Cragin'),
#  ('HM244120', 'CRIMINAL DAMAGE', 'STREET', 1.0, 'Rogers Park'),
#  ('HR342598', 'CRIMINAL DAMAGE', 'STREET', 31.0, 'Lower West Side'),
#  ('HL187666', 'CRIMINAL DAMAGE', 'BAR OR TAVERN', 24.0, 'West Town'),
#  ('HW449676', 'CRIMINAL DAMAGE', 'APARTMENT', 26.0, 'West Garfield Park'),
#  ('HS589302', 'CRIMINAL DAMAGE', 'RESIDENCE', 51.0, 'South Deering'),
#  ('HX145326', 'CRIMINAL DAMAGE', 'RESIDENCE', 30.0, 'South Lawndale'),
#  ('HN553354', 'CRIMINAL DAMAGE', 'RESIDENCE', 68.0, 'Englewood'),
#  ('HN784049', 'CRIMINAL DAMAGE', 'RESIDENCE', 70.0, 'Ashburn'),
#  ('HJ527694', 'CRIMINAL DAMAGE', 'RESIDENCE', 16.0, 'Irving Park'),
#  ('HM303461', 'CRIMINAL DAMAGE', 'VEHICLE NON-COMMERCIAL', 16.0, 'Irving Park'),
#  ('HM535632', 'CRIMINAL DAMAGE', 'RESIDENCE-GARAGE', 11.0, 'Jefferson Park'),
#  ('HT353855', 'CRIMINAL DAMAGE', 'STREET', 67.0, 'West Englewood'),
#  ('G134016', 'CRIMINAL DAMAGE', 'RESIDENCE', None, None),
#  ('HR125162', 'CRIMINAL DAMAGE', 'STREET', 62.0, 'West Elsdon'),
#  ('G496261', 'CRIMINAL DAMAGE', 'WAREHOUSE', None, None),
#  ('HJ842548', 'CRIMINAL DAMAGE', 'STREET', 24.0, 'West Town'),
#  ('HN280980', 'CRIMINAL DAMAGE', 'RESIDENCE', 5.0, 'North Center'),
#  ('JA560123', 'CRIMINAL DAMAGE', 'RESIDENCE', 18.0, 'Montclaire'),
#  ('HY405637', 'CRIMINAL DAMAGE', 'APARTMENT', 63.0, 'Gage Park'),
#  ('HP689703', 'CRIMINAL DAMAGE', 'RESIDENCE', 44.0, 'Chatham'),
#  ('HR345366', 'CRIMINAL DAMAGE', 'RESTAURANT', 24.0, 'West Town'),
#  ('HZ242802', 'CRIMINAL DAMAGE', 'RESIDENCE-GARAGE', 70.0, 'Ashburn'),
#  ('HM661326', 'CRIMINAL DAMAGE', 'STREET', 17.0, 'Dunning'),
#  ('HJ336995', 'CRIMINAL DAMAGE', 'RESIDENCE', 47.0, 'Burnside'),
#  ('HK694552', 'CRIMINAL DAMAGE', 'STREET', 43.0, 'South Shore'),
#  ('HJ760939', 'CRIMINAL DAMAGE', 'PARKING LOT/GARAGE(NON.RESID.)', 8.0, 'Near North Side'),
#  ('HV366181', 'CRIMINAL DAMAGE', 'STREET', 48.0, 'Calumet Heights'),
#  ('HJ563089', 'CRIMINAL DAMAGE', 'APARTMENT', 49.0, 'Roseland'),
#  ('HH576932', 'CRIMINAL DAMAGE', 'STREET', 71.0, 'Auburn Gresham'),
#  ('HR308948', 'CRIMINAL DAMAGE', 'SIDEWALK', 25.0, 'Austin'),
#  ('HK100758', 'CRIMINAL DAMAGE', 'STREET', 22.0, 'Logan Square'),
#  ('HV328581', 'NARCOTICS', 'OTHER COMMERCIAL TRANSPORTATION', 55.0, 'Hegewisch'),
#  ('HV267193', 'NARCOTICS', 'PARKING LOT/GARAGE(NON.RESID.)', 44.0, 'Chatham'),
#  ('HJ620738', 'NARCOTICS', 'SIDEWALK', 3.0, 'Uptown'),
#  ('HJ557529', 'NARCOTICS', 'SIDEWALK', 25.0, 'Austin'),
#  ('HS498920', 'NARCOTICS', 'STREET', 43.0, 'South Shore'),
#  ('HL608698', 'NARCOTICS', 'SIDEWALK', 27.0, 'East Garfield Park'),
#  ('G323273', 'NARCOTICS', 'SIDEWALK', None, None),
#  ('HK577020', 'NARCOTICS', 'SCHOOL, PUBLIC, GROUNDS', 1.0, 'Rogers Park'),
#  ('HY365876', 'NARCOTICS', 'STREET', 70.0, 'Ashburn'),
#  ('HS305355', 'NARCOTICS', 'SCHOOL, PUBLIC, BUILDING', 58.0, 'Brighton Park'),
#  ('HK162357', 'NARCOTICS', 'ALLEY', 25.0, 'Austin'),
#  ('HN778969', 'NARCOTICS', 'AIRPORT/AIRCRAFT', 76.0, "O'Hare"),
#  ('HV185969', 'NARCOTICS', 'SIDEWALK', 28.0, 'Near West Side'),
#  ('HH657604', 'NARCOTICS', 'SIDEWALK', 26.0, 'West Garfield Park'),
#  ('HW555338', 'NARCOTICS', 'POLICE FACILITY/VEH PARKING LOT', 29.0, 'North Lawndale'),
#  ('HV268708', 'NARCOTICS', 'APARTMENT', 3.0, 'Uptown'),
#  ('G170513', 'NARCOTICS', 'SIDEWALK', None, None),
#  ('HW160463', 'NARCOTICS', 'SIDEWALK', 69.0, 'Greater Grand Crossing'),
#  ('HN355411', 'NARCOTICS', 'SIDEWALK', 25.0, 'Austin'),
#  ('HK190723', 'NARCOTICS', 'STREET', 68.0, 'Englewood'),
#  ('HV457847', 'NARCOTICS', 'SIDEWALK', 29.0, 'North Lawndale'),
#  ('HW566855', 'NARCOTICS', 'SIDEWALK', 28.0, 'Near West Side'),
#  ('HL141298', 'NARCOTICS', 'OTHER', 3.0, 'Uptown'),
#  ('HR281750', 'NARCOTICS', 'VEHICLE NON-COMMERCIAL', 46.0, 'South Chicago'),
#  ('HL342355', 'NARCOTICS', 'STREET', 58.0, 'Brighton Park'),
#  ('HX112183', 'NARCOTICS', 'ALLEY', 63.0, 'Gage Park'),
#  ('HJ624999', 'NARCOTICS', 'SIDEWALK', 38.0, 'Grand Boulevard'),
#  ('HJ618818', 'NARCOTICS', 'STREET', 27.0, 'East Garfield Park'),
#  ('HR597126', 'NARCOTICS', 'RESIDENTIAL YARD (FRONT/BACK)', 66.0, 'Chicago Lawn'),
#  ('HN558484', 'NARCOTICS', 'STREET', 71.0, 'Auburn Gresham'),
#  ('HR505781', 'NARCOTICS', 'ALLEY', 23.0, 'Humboldt park'),
#  ('HN522324', 'NARCOTICS', 'SIDEWALK', 61.0, 'New City'),
#  ('HN647052', 'NARCOTICS', 'GAS STATION', 42.0, 'Woodlawn'),
#  ('HT323138', 'NARCOTICS', 'STREET', 42.0, 'Woodlawn'),
#  ('HW562748', 'NARCOTICS', 'PARKING LOT/GARAGE(NON.RESID.)', 25.0, 'Austin'),
#  ('HN719188', 'NARCOTICS', 'STREET', 61.0, 'New City'),
#  ('HT237921', 'NARCOTICS', 'STREET', 31.0, 'Lower West Side'),
#  ('HY215032', 'NARCOTICS', 'SIDEWALK', 26.0, 'West Garfield Park'),
#  ('HK369511', 'NARCOTICS', 'STREET', 28.0, 'Near West Side'),
#  ('HL703172', 'NARCOTICS', 'SIDEWALK', 23.0, 'Humboldt park'),
#  ('HM762800', 'NARCOTICS', 'SIDEWALK', 53.0, 'West Pullman'),
#  ('HN370211', 'NARCOTICS', 'STREET', 3.0, 'Uptown'),
#  ('HR195962', 'NARCOTICS', 'SIDEWALK', 29.0, 'North Lawndale'),
#  ('HM284854', 'NARCOTICS', 'SIDEWALK', 23.0, 'Humboldt park'),
#  ('HL319228', 'NARCOTICS', 'STREET', 23.0, 'Humboldt park'),
#  ('HR447925', 'NARCOTICS', 'APARTMENT', 23.0, 'Humboldt park'),
#  ('HM590293', 'NARCOTICS', 'STREET', 23.0, 'Humboldt park'),
#  ('HP513177', 'NARCOTICS', 'STREET', 15.0, 'Portage Park'),
#  ('HL331611', 'NARCOTICS', 'SIDEWALK', 25.0, 'Austin'),
#  ('HN448271', 'NARCOTICS', 'SIDEWALK', 25.0, 'Austin'),
#  ('HH402660', 'NARCOTICS', 'STREET', 25.0, 'Austin'),
#  ('HN422493', 'NARCOTICS', 'PARKING LOT/GARAGE(NON.RESID.)', 69.0, 'Greater Grand Crossing'),
#  ('HP263901', 'NARCOTICS', 'STREET', 58.0, 'Brighton Park'),
#  ('G577663', 'NARCOTICS', 'STREET', 66.0, 'Chicago Lawn'),
#  ('HT535175', 'OTHER OFFENSE', 'APARTMENT', 14.0, 'Albany Park'),
#  ('JA110097', 'OTHER OFFENSE', 'RESIDENCE', 22.0, 'Logan Square'),
#  ('HM360756', 'OTHER OFFENSE', 'RESIDENCE', 1.0, 'Rogers Park'),
#  ('HN275969', 'OTHER OFFENSE', 'DRUG STORE', 23.0, 'Humboldt park'),
#  ('HZ544441', 'OTHER OFFENSE', 'APARTMENT', 61.0, 'New City'),
#  ('HL660560', 'OTHER OFFENSE', 'RESIDENCE', 62.0, 'West Elsdon'),
#  ('HS164946', 'OTHER OFFENSE', 'RESIDENCE', 6.0, 'Lake View'),
#  ('HR399710', 'OTHER OFFENSE', 'RESIDENCE', 31.0, 'Lower West Side'),
#  ('HP243837', 'OTHER OFFENSE', 'APARTMENT', 8.0, 'Near North Side'),
#  ('HP157774', 'OTHER OFFENSE', 'APARTMENT', 19.0, 'Belmont Cragin'),
#  ('HP340132', 'OTHER OFFENSE', 'APARTMENT', 39.0, 'Kenwood'),
#  ('HJ388435', 'OTHER OFFENSE', 'APARTMENT', 42.0, 'Woodlawn'),
#  ('JA246453', 'OTHER OFFENSE', 'APARTMENT', 23.0, 'Humboldt park'),
#  ('HN407116', 'OTHER OFFENSE', 'OTHER', 15.0, 'Portage Park'),
#  ('JA107722', 'OTHER OFFENSE', 'RESIDENCE', 18.0, 'Montclaire'),
#  ('HJ532105', 'OTHER OFFENSE', 'APARTMENT', 21.0, 'Avondale'),
#  ('HH729144', 'OTHER OFFENSE', 'APARTMENT', 2.0, 'West Ridge'),
#  ('HY204891', 'OTHER OFFENSE', 'SIDEWALK', 23.0, 'Humboldt park'),
#  ('HZ228967', 'OTHER OFFENSE', 'APARTMENT', 25.0, 'Austin'),
#  ('HY385205', 'OTHER OFFENSE', 'APARTMENT', 67.0, 'West Englewood'),
#  ('HK328402', 'OTHER OFFENSE', 'VEHICLE NON-COMMERCIAL', 51.0, 'South Deering'),
#  ('JA349450', 'OTHER OFFENSE', 'PARKING LOT/GARAGE(NON.RESID.)', 46.0, 'South Chicago'),
#  ('HK743113', 'OTHER OFFENSE', 'APARTMENT', 44.0, 'Chatham'),
#  ('HR185873', 'OTHER OFFENSE', 'RESIDENCE', 69.0, 'Greater Grand Crossing'),
#  ('HH692211', 'OTHER OFFENSE', 'STREET', 26.0, 'West Garfield Park'),
#  ('JA470839', 'OTHER OFFENSE', 'RESIDENCE', 45.0, 'Avalon Park'),
#  ('HY182950', 'OTHER OFFENSE', 'APARTMENT', 24.0, 'West Town'),
#  ('HR668156', 'OTHER OFFENSE', 'RESIDENCE', 68.0, 'Englewood'),
#  ('HZ234518', 'OTHER OFFENSE', 'APARTMENT', 58.0, 'Brighton Park'),
#  ('HW569852', 'OTHER OFFENSE', 'RESIDENCE', 25.0, 'Austin'),
#  ('HS314108', 'OTHER OFFENSE', 'APARTMENT', 2.0, 'West Ridge'),
#  ('HH463517', 'OTHER OFFENSE', 'COMMERCIAL / BUSINESS OFFICE', 8.0, 'Near North Side'),
#  ('HN182437', 'ASSAULT', 'SIDEWALK', 44.0, 'Chatham'),
#  ('HW493063', 'ASSAULT', 'ALLEY', 25.0, 'Austin'),
#  ('HJ637197', 'ASSAULT', 'SIDEWALK', 23.0, 'Humboldt park'),
#  ('HH829588', 'ASSAULT', 'STREET', 25.0, 'Austin'),
#  ('HZ322965', 'ASSAULT', 'PARKING LOT/GARAGE(NON.RESID.)', 33.0, 'Near South Side'),
#  ('HW415978', 'ASSAULT', 'SIDEWALK', 25.0, 'Austin'),
#  ('HL315870', 'ASSAULT', 'SIDEWALK', 31.0, 'Lower West Side'),
#  ('HJ222529', 'ASSAULT', 'OTHER', 51.0, 'South Deering'),
#  ('HM535930', 'ASSAULT', 'STREET', 49.0, 'Roseland'),
#  ('HZ242203', 'ASSAULT', 'APARTMENT', 27.0, 'East Garfield Park'),
#  ('HN213069', 'ASSAULT', 'RESIDENCE', 68.0, 'Englewood'),
#  ('HH343366', 'ASSAULT', 'RESIDENCE PORCH/HALLWAY', 6.0, 'Lake View'),
#  ('JA269772', 'ASSAULT', 'STREET', 26.0, 'West Garfield Park'),
#  ('HH106347', 'ASSAULT', 'STREET', None, None),
#  ('HM507529', 'ASSAULT', 'RESIDENCE', 68.0, 'Englewood'),
#  ('HP258815', 'ASSAULT', 'COMMERCIAL / BUSINESS OFFICE', 72.0, 'Beverly'),
#  ('HL111533', 'ASSAULT', 'HOSPITAL BUILDING/GROUNDS', 38.0, 'Grand Boulevard'),
#  ('HS479338', 'ASSAULT', 'CHA APARTMENT', 45.0, 'Avalon Park'),
#  ('HZ403432', 'ASSAULT', 'APARTMENT', 42.0, 'Woodlawn'),
#  ('HV462975', 'ASSAULT', 'STREET', 63.0, 'Gage Park'),
#  ('HW414519', 'ASSAULT', 'SIDEWALK', 38.0, 'Grand Boulevard'),
#  ('HL414306', 'ASSAULT', 'APARTMENT', 71.0, 'Auburn Gresham'),
#  ('HT315369', 'ASSAULT', 'SCHOOL, PUBLIC, GROUNDS', 27.0, 'East Garfield Park'),
#  ('HL330223', 'ASSAULT', 'OTHER', 8.0, 'Near North Side'),
#  ('HK751265', 'ASSAULT', 'STREET', 71.0, 'Auburn Gresham'),
#  ('HT540548', 'ASSAULT', 'RESIDENCE', 68.0, 'Englewood'),
#  ('HX398190', 'ASSAULT', 'SIDEWALK', 49.0, 'Roseland'),
#  ('HK348713', 'ASSAULT', 'OTHER', 43.0, 'South Shore'),
#  ('HR206683', 'ASSAULT', 'RESIDENCE PORCH/HALLWAY', 25.0, 'Austin'),
#  ('HH154448', 'ASSAULT', 'RESIDENCE', None, None),
#  ('JA462321', 'ASSAULT', 'APARTMENT', 68.0, 'Englewood'),
#  ('HV233824', 'ASSAULT', 'OTHER', 28.0, 'Near West Side'),
#  ('HR307075', 'BURGLARY', 'APARTMENT', 25.0, 'Austin'),
#  ('HZ134318', 'BURGLARY', 'RESIDENCE', 49.0, 'Roseland'),
#  ('HM437597', 'BURGLARY', 'FACTORY/MANUFACTURING BUILDING', 46.0, 'South Chicago'),
#  ('HW233866', 'BURGLARY', 'APARTMENT', 29.0, 'North Lawndale'),
#  ('G659211', 'BURGLARY', 'RESIDENCE PORCH/HALLWAY', None, None),
#  ('HW274134', 'BURGLARY', 'RESIDENCE', 19.0, 'Belmont Cragin'),
#  ('HW526270', 'BURGLARY', 'RESIDENCE', 24.0, 'West Town'),
#  ('G375927', 'BURGLARY', 'RESIDENCE-GARAGE', None, None),
#  ('HP325677', 'BURGLARY', 'RESTAURANT', 25.0, 'Austin'),
#  ('HL300450', 'BURGLARY', 'CONSTRUCTION SITE', 53.0, 'West Pullman'),
#  ('HN246122', 'BURGLARY', 'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 61.0, 'New City'),
#  ('HH149573', 'BURGLARY', 'SMALL RETAIL STORE', None, None),
#  ('HK450946', 'BURGLARY', 'RESIDENCE', 7.0, 'Lincoln Park'),
#  ('HT434553', 'BURGLARY', 'RESIDENCE-GARAGE', 65.0, 'West Lawn'),
#  ('HL548996', 'BURGLARY', 'APARTMENT', 69.0, 'Greater Grand Crossing'),
#  ('HR696852', 'BURGLARY', 'RESIDENCE-GARAGE', 52.0, 'East Side'),
#  ('HK481967', 'BURGLARY', 'COMMERCIAL / BUSINESS OFFICE', 20.0, 'Hermosa'),
#  ('HT202584', 'BURGLARY', 'APARTMENT', 69.0, 'Greater Grand Crossing'),
#  ('HJ409442', 'BURGLARY', 'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 30.0, 'South Lawndale'),
#  ('HT251336', 'BURGLARY', 'RESIDENCE', 72.0, 'Beverly'),
#  ('HV575905', 'BURGLARY', 'RESIDENCE-GARAGE', 17.0, 'Dunning'),
#  ('HR489129', 'BURGLARY', 'RESIDENCE', 17.0, 'Dunning'),
#  ('HT427568', 'BURGLARY', 'CLEANING STORE', 72.0, 'Beverly'),
#  ('HR539548', 'BURGLARY', 'RESIDENCE-GARAGE', 48.0, 'Calumet Heights'),
#  ('HS426544', 'BURGLARY', 'APARTMENT', 68.0, 'Englewood'),
#  ('HT556032', 'BURGLARY', 'RESIDENCE', 43.0, 'South Shore'),
#  ('HL254965', 'BURGLARY', 'RESIDENCE', 71.0, 'Auburn Gresham'),
#  ('JA216127', 'BURGLARY', 'RESIDENCE', 67.0, 'West Englewood'),
#  ('HW350078', 'BURGLARY', 'RESIDENCE', 68.0, 'Englewood'),
#  ('HR308245', 'BURGLARY', 'APARTMENT', 25.0, 'Austin'),
#  ('HY455377', 'MOTOR VEHICLE THEFT', 'STREET', 67.0, 'West Englewood'),
#  ('HP747058', 'MOTOR VEHICLE THEFT', 'STREET', 68.0, 'Englewood'),
#  ('HN645348', 'MOTOR VEHICLE THEFT', 'STREET', 16.0, 'Irving Park'),
#  ('HL334216', 'MOTOR VEHICLE THEFT', 'STREET', 46.0, 'South Chicago'),
#  ('HS230740', 'MOTOR VEHICLE THEFT', 'STREET', 16.0, 'Irving Park'),
#  ('HV593288', 'MOTOR VEHICLE THEFT', 'STREET', 28.0, 'Near West Side'),
#  ('HK341632', 'MOTOR VEHICLE THEFT', 'STREET', 48.0, 'Calumet Heights'),
#  ('HH859922', 'MOTOR VEHICLE THEFT', 'STREET', 41.0, 'Hyde Park'),
#  ('G611731', 'MOTOR VEHICLE THEFT', 'STREET', None, None),
#  ('HM757133', 'MOTOR VEHICLE THEFT', 'STREET', 31.0, 'Lower West Side'),
#  ('HJ786817', 'MOTOR VEHICLE THEFT', 'STREET', 22.0, 'Logan Square'),
#  ('HV356669', 'MOTOR VEHICLE THEFT', 'STREET', 42.0, 'Woodlawn'),
#  ('HX207970', 'MOTOR VEHICLE THEFT', 'STREET', 26.0, 'West Garfield Park'),
#  ('HM733422', 'MOTOR VEHICLE THEFT', 'STREET', 28.0, 'Near West Side'),
#  ('HH352862', 'MOTOR VEHICLE THEFT', 'OTHER', 69.0, 'Greater Grand Crossing'),
#  ('G652158', 'MOTOR VEHICLE THEFT', 'STREET', None, None),
#  ('HX301095', 'MOTOR VEHICLE THEFT', 'STREET', 68.0, 'Englewood'),
#  ('HY163644', 'MOTOR VEHICLE THEFT', 'STREET', 66.0, 'Chicago Lawn'),
#  ('HR140766', 'MOTOR VEHICLE THEFT', 'STREET', 25.0, 'Austin'),
#  ('HH605275', 'MOTOR VEHICLE THEFT', 'STREET', 63.0, 'Gage Park'),
#  ('HJ513676', 'MOTOR VEHICLE THEFT', 'ALLEY', 71.0, 'Auburn Gresham'),
#  ('HH337319', 'MOTOR VEHICLE THEFT', 'STREET', 19.0, 'Belmont Cragin'),
#  ('HH423186', 'MOTOR VEHICLE THEFT', 'STREET', 58.0, 'Brighton Park'),
#  ('HN543219', 'MOTOR VEHICLE THEFT', 'STREET', 66.0, 'Chicago Lawn'),
#  ('HZ463811', 'DECEPTIVE PRACTICE', 'CTA TRAIN', 76.0, "O'Hare"),
#  ('HN702776', 'DECEPTIVE PRACTICE', 'RESTAURANT', 8.0, 'Near North Side'),
#  ('HR607189', 'DECEPTIVE PRACTICE', 'RESTAURANT', 2.0, 'West Ridge'),
#  ('G654957', 'DECEPTIVE PRACTICE', 'BANK', None, None),
#  ('HL131736', 'DECEPTIVE PRACTICE', 'RESIDENCE', 71.0, 'Auburn Gresham'),
#  ('HN519755', 'DECEPTIVE PRACTICE', 'STREET', 24.0, 'West Town'),
#  ('G629024', 'DECEPTIVE PRACTICE', 'OTHER', None, None),
#  ('HL239939', 'DECEPTIVE PRACTICE', 'STREET', 8.0, 'Near North Side'),
#  ('HK328522', 'DECEPTIVE PRACTICE', 'CTA PLATFORM', 1.0, 'Rogers Park'),
#  ('HJ349966', 'DECEPTIVE PRACTICE', 'RESIDENCE', 70.0, 'Ashburn'),
#  ('G345035', 'DECEPTIVE PRACTICE', 'BANK', None, None),
#  ('JA394755', 'DECEPTIVE PRACTICE', 'RESIDENCE', 24.0, 'West Town'),
#  ('HY518743', 'DECEPTIVE PRACTICE', 'RESIDENCE', 71.0, 'Auburn Gresham'),
#  ('JA550741', 'DECEPTIVE PRACTICE', 'OTHER', 16.0, 'Irving Park'),
#  ('HH493814', 'DECEPTIVE PRACTICE', 'RESTAURANT', 6.0, 'Lake View'),
#  ('HZ523997', 'DECEPTIVE PRACTICE', 'APARTMENT', 25.0, 'Austin'),
#  ('G161722', 'DECEPTIVE PRACTICE', 'CTA PLATFORM', None, None),
#  ('HY455698', 'DECEPTIVE PRACTICE', 'BANK', 20.0, 'Hermosa'),
#  ('HH208082', 'DECEPTIVE PRACTICE', 'AIRPORT/AIRCRAFT', None, None),
#  ('HT404945', 'DECEPTIVE PRACTICE', 'RESIDENCE', 46.0, 'South Chicago'),
#  ('HL213843', 'ROBBERY', 'STREET', 38.0, 'Grand Boulevard'),
#  ('HM422467', 'ROBBERY', 'STREET', 2.0, 'West Ridge'),
#  ('JA192460', 'ROBBERY', 'STREET', 29.0, 'North Lawndale'),
#  ('HL446401', 'ROBBERY', 'STREET', 30.0, 'South Lawndale'),
#  ('HS330202', 'ROBBERY', 'STREET', 53.0, 'West Pullman'),
#  ('HP661088', 'ROBBERY', 'STREET', 23.0, 'Humboldt park'),
#  ('HJ281736', 'ROBBERY', 'STREET', 71.0, 'Auburn Gresham'),
#  ('HN136243', 'ROBBERY', 'RESTAURANT', 5.0, 'North Center'),
#  ('HJ580490', 'ROBBERY', 'PARKING LOT/GARAGE(NON.RESID.)', 23.0, 'Humboldt park'),
#  ('HV213648', 'ROBBERY', 'RESIDENCE', 67.0, 'West Englewood'),
#  ('HV514287', 'ROBBERY', 'SIDEWALK', 14.0, 'Albany Park'),
#  ('HJ753917', 'ROBBERY', 'GAS STATION', 15.0, 'Portage Park'),
#  ('JA133264', 'ROBBERY', 'STREET', 25.0, 'Austin'),
#  ('HJ642080', 'ROBBERY', 'STREET', 10.0, 'Norwood Park'),
#  ('JA557966', 'ROBBERY', 'VEHICLE NON-COMMERCIAL', 28.0, 'Near West Side'),
#  ('HV548880', 'ROBBERY', 'GAS STATION', 69.0, 'Greater Grand Crossing'),
#  ('HR480844', 'ROBBERY', 'STREET', 53.0, 'West Pullman'),
#  ('HW568748', 'ROBBERY', 'RESIDENTIAL YARD (FRONT/BACK)', 44.0, 'Chatham'),
#  ('HH405177', 'ROBBERY', 'STREET', 26.0, 'West Garfield Park'),
#  ('HL472862', 'ROBBERY', 'ALLEY', 49.0, 'Roseland'),
#  ('G326063', 'CRIMINAL TRESPASS', 'CHA PARKING LOT/GROUNDS', None, None),
#  ('HL424420', 'CRIMINAL TRESPASS', 'CHA PARKING LOT/GROUNDS', 35.0, 'Douglas'),
#  ('JA393243', 'CRIMINAL TRESPASS', 'RESIDENCE', 49.0, 'Roseland'),
#  ('HR585012', 'CRIMINAL TRESPASS', 'SCHOOL, PUBLIC, GROUNDS', 70.0, 'Ashburn'),
#  ('JA455629', 'CRIMINAL TRESPASS', 'RESTAURANT', 71.0, 'Auburn Gresham'),
#  ('HV369974', 'CRIMINAL TRESPASS', 'ALLEY', 66.0, 'Chicago Lawn'),
#  ('HN637742', 'CRIMINAL TRESPASS', 'GAS STATION', 22.0, 'Logan Square'),
#  ('HW557360', 'CRIMINAL TRESPASS', 'LIBRARY', 32.0, 'Loop'),
#  ('HJ776916', 'CRIMINAL TRESPASS', 'CHA HALLWAY/STAIRWELL/ELEVATOR', 28.0, 'Near West Side'),
#  ('HJ419340', 'CRIMINAL TRESPASS', 'COLLEGE/UNIVERSITY GROUNDS', 35.0, 'Douglas'),
#  ('HH329720', 'CRIMINAL TRESPASS', 'CHA PARKING LOT/GROUNDS', 35.0, 'Douglas'),
#  ('HM802052', 'CRIMINAL TRESPASS', 'STREET', 38.0, 'Grand Boulevard'),
#  ('HJ804627', 'CRIMINAL TRESPASS', 'BANK', 32.0, 'Loop'),
#  ('HR190881', 'CRIMINAL TRESPASS', 'BANK', 4.0, 'Lincoln Square'),
#  ('G575031', 'CRIMINAL TRESPASS', 'PARKING LOT/GARAGE(NON.RESID.)', None, None),
#  ('G122095', 'PROSTITUTION', 'RESIDENCE', None, None),
#  ('HN595319', 'PROSTITUTION', 'SIDEWALK', 1.0, 'Rogers Park'),
#  ('G302291', 'PROSTITUTION', 'STREET', None, None),
#  ('G057394', 'PROSTITUTION', 'STREET', None, None),
#  ('HM590468', 'PROSTITUTION', 'STREET', 8.0, 'Near North Side'),
#  ('HV463112', 'PROSTITUTION', 'STREET', 25.0, 'Austin'),
#  ('HK749575', 'WEAPONS VIOLATION', 'RESIDENCE', 25.0, 'Austin'),
#  ('HS100098', 'WEAPONS VIOLATION', 'RESIDENCE', 66.0, 'Chicago Lawn'),
#  ('HW576249', 'WEAPONS VIOLATION', 'RESIDENCE', 29.0, 'North Lawndale'),
#  ('HK485601', 'WEAPONS VIOLATION', 'SIDEWALK', 67.0, 'West Englewood'),
#  ('HH460583', 'WEAPONS VIOLATION', 'STREET', 22.0, 'Logan Square'),
#  ('HM576559', 'WEAPONS VIOLATION', 'RESIDENCE', 46.0, 'South Chicago'),
#  ('HL611297', 'PUBLIC PEACE VIOLATION', 'SIDEWALK', 63.0, 'Gage Park'),
#  ('HV356389', 'PUBLIC PEACE VIOLATION', 'STREET', 56.0, 'Garfield Ridge'),
#  ('HX203242', 'PUBLIC PEACE VIOLATION', 'SIDEWALK', 42.0, 'Woodlawn'),
#  ('HH292682', 'PUBLIC PEACE VIOLATION', 'SCHOOL, PRIVATE, BUILDING', None, None),
#  ('G635735', 'PUBLIC PEACE VIOLATION', 'SCHOOL, PUBLIC, BUILDING', None, None),
#  ('HN567387', 'OFFENSE INVOLVING CHILDREN', 'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 21.0, 'Avondale'),
#  ('HR391350', 'OFFENSE INVOLVING CHILDREN', 'APARTMENT', 29.0, 'North Lawndale'),
#  ('HM768251', 'OFFENSE INVOLVING CHILDREN', 'RESIDENCE', 70.0, 'Ashburn'),
#  ('HT394616', 'OFFENSE INVOLVING CHILDREN', 'RESIDENCE', 43.0, 'South Shore'),
#  ('HH688935', 'CRIM SEXUAL ASSAULT', 'ALLEY', 68.0, 'Englewood'),
#  ('HK677648', 'CRIM SEXUAL ASSAULT', 'APARTMENT', 20.0, 'Hermosa'),
#  ('G158614', 'CRIM SEXUAL ASSAULT', 'ALLEY', None, None),
#  ('HK310265', 'SEX OFFENSE', 'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 12.0, 'Forest Glen'),
#  ('HR314298', 'SEX OFFENSE', 'STREET', 61.0, 'New City'),
#  ('HT404326', 'SEX OFFENSE', 'RESIDENCE PORCH/HALLWAY', 19.0, 'Belmont Cragin'),
#  ('HY259084', 'INTERFERENCE WITH PUBLIC OFFICER', 'STREET', 67.0, 'West Englewood'),
#  ('HL415544', 'INTERFERENCE WITH PUBLIC OFFICER', 'POLICE FACILITY/VEH PARKING LOT', 27.0, 'East Garfield Park'),
#  ('HP265256', 'GAMBLING', 'SIDEWALK', 8.0, 'Near North Side'),
#  ('HR392537', 'GAMBLING', 'SIDEWALK', 66.0, 'Chicago Lawn'),
#  ('HL266884', 'LIQUOR LAW VIOLATION', 'CONVENIENCE STORE', 7.0, 'Lincoln Park'),
#  ('HK238408', 'LIQUOR LAW VIOLATION', 'ALLEY', 48.0, 'Calumet Heights'),
#  ('HX343113', 'ARSON', 'RESIDENCE', 54.0, 'Riverdale'),
#  ('HM195342', 'ARSON', 'RESIDENCE', 53.0, 'West Pullman'),
#  ('HW519443', 'HOMICIDE', 'HOUSE', 58.0, 'Brighton Park'),
#  ('JA359626', 'HOMICIDE', 'STREET', 45.0, 'Avalon Park'),
#  ('HN144152', 'KIDNAPPING', 'STREET', 25.0, 'Austin'),
#  ('HN544458', 'INTIMIDATION', 'SMALL RETAIL STORE', 45.0, 'Avalon Park'),
#  ('HW238778', 'STALKING', 'RESIDENCE', 16.0, 'Irving Park'),
#  ('JB155558', 'OBSCENITY', 'RESIDENCE', 70.0, 'Ashburn'),
#  ('HY458571', 'CONCEALED CARRY LICENSE VIOLATION', 'SIDEWALK', 25.0, 'Austin'),
#  ('HZ378869', 'PUBLIC INDECENCY', 'SIDEWALK', 71.0, 'Auburn Gresham'),
#  ('HZ378355', 'NON-CRIMINAL', 'GOVERNMENT BUILDING/PROPERTY', 11.0, 'Jefferson Park'),
#  ('HX258445', 'OTHER NARCOTIC VIOLATION', 'SIDEWALK', 8.0, 'Near North Side'),
#  ('HZ192829', 'HUMAN TRAFFICKING', 'APARTMENT', 46.0, 'South Chicago'),
#  ('HZ133234', 'NON - CRIMINAL', 'STREET', 28.0, 'Near West Side'),
#  ('HJ747227', 'RITUALISM', 'OTHER', 71.0, 'Auburn Gresham'),
#  ('JA143710', 'NON-CRIMINAL (SUBJECT SPECIFIED)', 'RESIDENCE', 23.0, 'Humboldt park'),
#  ('G021609', 'DOMESTIC VIOLENCE', 'APARTMENT', None, None)]

# %%
# %%sql SELECT CCD.Case_Number, CCD.Primary_Type, CCD.Location_Description, CD.Community_Area_Name, CD. Community_Area_Number
# from CHICAGO_CRIME_DATA as CCD
# RIGHT OUTER JOIN CENSUS_DATA as CD
# ON CD. Community_Area_Number = CCD. Community_Area_Number;
# Out:
#  * sqlite:///RealWorldData.db
# (sqlite3.OperationalError) RIGHT and FULL OUTER JOINs are not currently supported
# [SQL: SELECT CCD.Case_Number, CCD.Primary_Type, CCD.Location_Description, CD.Community_Area_Name, CD. Community_Area_Number
# from CHICAGO_CRIME_DATA as CCD
# RIGHT OUTER JOIN CENSUS_DATA as CD
# ON CD. Community_Area_Number = CCD. Community_Area_Number;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %%sql SELECT CCD.Case_Number, CCD.Primary_Type, CCD.Location_Description, CCD. Community_Area_Number,
# CD.Community_Area_Name, CD.Community_Area_Number, CD.Percent_Households_Below_Poverty
# from CHICAGO_CRIME_DATA as CCD
# FULL OUTER JOIN CENSUS_DATA as CD
# ON CD. Community_Area_Number = CCD. Community_Area_Number;
# Out:
#  * sqlite:///RealWorldData.db
# (sqlite3.OperationalError) RIGHT and FULL OUTER JOINs are not currently supported
# [SQL: SELECT CCD.Case_Number, CCD.Primary_Type, CCD.Location_Description, CCD. Community_Area_Number,
# CD.Community_Area_Name, CD.Community_Area_Number, CD.Percent_Households_Below_Poverty
# from CHICAGO_CRIME_DATA as CCD
# FULL OUTER JOIN CENSUS_DATA as CD
# ON CD. Community_Area_Number = CCD. Community_Area_Number;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ## Author(s)
#
# <h4> Hima Vasudevan </h4>
# <h4> Rav Ahuja </h4>
# <h4> Ramesh Sannreddy </h4>
#
# ## Contribtuor(s)
#
# <h4> Malika Singla </h4>
#
# ## Change log
#
# | Date       | Version | Changed by        | Change Description                             |
# | ---------- | ------- | ----------------- | ---------------------------------------------- |
# | 2022-03-04 | 2.5     | Lakshmi Holla     | Changed markdown.                              |
# | 2021-05-19 | 2.4     | Lakshmi Holla     | Updated the question                           |
# | 2021-04-30 | 2.3     | Malika Singla     | Updated the libraries                          |
# | 2021-01-15 | 2.2     | Rav Ahuja         | Removed problem 11 and fixed changelog         |
# | 2020-11-25 | 2.1     | Ramesh Sannareddy | Updated the problem statements, and datasets   |
# | 2020-09-05 | 2.0     | Malika Singla     | Moved lab to course repo in GitLab             |
# | 2018-07-18 | 1.0     | Rav Ahuja         | Several updates including loading instructions |
# | 2018-05-04 | 0.1     | Hima Vasudevan    | Created initial version                        |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %%
select CCD.Case_Number, CCD.Primary_Type, CCD. Community_Area_Number, CD.Community_Area_Name
from CHICAGO_CRIME_DATA as CCD
LEFT OUTER JOIN CENSUS_DATA as CD
on CCD. Community_Area_Number = CD. Community_Area_Number
